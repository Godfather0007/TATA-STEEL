# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %%
df = pd.read_csv('TATASTEEL.NS.csv')

# %%
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2018-10-08   56.700001   56.994999   54.400002   55.980000   22.389208
# 1     2018-10-09   56.000000   58.389999   55.455002   57.250000   22.897142
# 2     2018-10-10   57.314999   58.779999   57.314999   58.365002   23.343088
# 3     2018-10-11   55.700001   56.400002   54.904999   55.514999   22.203232
# 4     2018-10-12   56.080002   57.880001   55.810001   57.650002   23.057125
# ...          ...         ...         ...         ...         ...         ...
# 1231  2023-09-29  128.199997  129.550003  127.550003  128.899994  128.899994
# 1232  2023-10-03  129.000000  129.100006  127.250000  128.000000  128.000000
# 1233  2023-10-04  127.000000  127.099998  124.500000  125.300003  125.300003
# 1234  2023-10-05  125.900002  126.150002  124.550003  125.250000  125.250000
# 1235  2023-10-06  126.500000  127.000000  125.099998  125.900002  125.900002
#
#          Volume
# 0      91710480
# 1      77344340
# 2      71533140
# 3     104016430
# 4      57334070
# ...         ...
# 1231   28406435
# 1232   18613557
# 1233   33272725
# 1234   27063441
# 1235   21928671
#
# [1236 rows x 7 columns]

# %%
df = df[['Date', 'Close']]


df['Date'] = pd.to_datetime(df['Date'])


df.set_index('Date', inplace=True)


df.sort_index(ascending=True, inplace=True)


scaler = MinMaxScaler()
df['Close'] = scaler.fit_transform(df['Close'].values.reshape(-1, 1))


plt.figure(figsize=(12, 6))
plt.title('Normalized Stock Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Normalized Close Price')
plt.plot(df.index, df['Close'])
plt.show()
# Out:
# <ipython-input-4-6a5131efa009>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = pd.to_datetime(df['Date'])
# <ipython-input-4-6a5131efa009>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Close'] = scaler.fit_transform(df['Close'].values.reshape(-1, 1))

# %%
train_size = int(len(df) * 0.8)
train_data = df.iloc[:train_size]
test_data = df.iloc[train_size:]

# %%
def create_sequences(data, sequence_length):
    sequences = []
    target = []

    for i in range(len(data) - sequence_length):
        x = data[i:i+sequence_length]
        y = data[i:i+sequence_length]
        sequences.append(x)
        target.append(y)

    return np.array(sequences), np.array(target)

sequence_length = 10
X_train, y_train = create_sequences(train_data, sequence_length)
X_test, y_test = create_sequences(test_data, sequence_length)

# %%
model = Sequential()

model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.fit(X_train, y_train, batch_size=64, epochs=50)
# Out:
# Epoch 1/50
# 16/16 [==============================] - 5s 17ms/step - loss: 0.0517
# Epoch 2/50
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0062
# Epoch 3/50
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0015
# Epoch 4/50
# 16/16 [==============================] - 0s 17ms/step - loss: 7.1846e-04
# Epoch 5/50
# 16/16 [==============================] - 0s 17ms/step - loss: 5.0581e-04
# Epoch 6/50
# 16/16 [==============================] - 0s 17ms/step - loss: 4.8044e-04
# Epoch 7/50
# 16/16 [==============================] - 0s 15ms/step - loss: 4.7353e-04
# Epoch 8/50
# 16/16 [==============================] - 0s 16ms/step - loss: 4.7040e-04
# Epoch 9/50
# 16/16 [==============================] - 0s 17ms/step - loss: 4.6846e-04
# Epoch 10/50
# 16/16 [==============================] - 0s 17ms/step - loss: 4.6722e-04
# Epoch 11/50
# 16/16 [==============================] - 0s 16ms/step - loss: 4.6661e-04
# Epoch 12/50
# 16/16 [==============================] - 0s 16ms/step - loss: 4.6572e-04
# Epoch 13/50
# 16/16 [==============================] - 0s 17ms/step - loss: 4.6431e-04
# Epoch 14/50
# 16/16 [==============================] - 0s 15ms/step - loss: 4.6360e-04
# Epoch 15/50
# 16/16 [==============================] - 0s 16ms/step - loss: 4.6342e-04
# Epoch 16/50
# 16/16 [==============================] - 0s 17ms/step - loss: 4.6243e-04
# Epoch 17/50
# 16/16 [==============================] - 0s 26ms/step - loss: 4.6209e-04
# Epoch 18/50
# 16/16 [==============================] - 0s 25ms/step - loss: 4.6171e-04
# Epoch 19/50
# 16/16 [==============================] - 0s 26ms/step - loss: 4.6144e-04
# Epoch 20/50
# 16/16 [==============================] - 0s 26ms/step - loss: 4.6105e-04
# Epoch 21/50
# 16/16 [==============================] - 0s 28ms/step - loss: 4.6089e-04
# Epoch 22/50
# 16/16 [==============================] - 0s 27ms/step - loss: 4.6078e-04
# Epoch 23/50
# 16/16 [==============================] - 0s 25ms/step - loss: 4.6096e-04
# Epoch 24/50
# 16/16 [==============================] - 0s 21ms/step - loss: 4.6050e-04
# Epoch 25/50
# 16/16 [==============================] - 0s 17ms/step - loss: 4.6047e-04
# Epoch 26/50
# 16/16 [==============================] - 0s 17ms/step - loss: 4.6060e-04
# Epoch 27/50
# 16/16 [==============================] - 0s 16ms/step - loss: 4.6040e-04
# Epoch 28/50
# 16/16 [==============================] - 0s 18ms/step - loss: 4.6032e-04
# Epoch 29/50
# 16/16 [==============================] - 0s 17ms/step - loss: 4.6037e-04
# Epoch 30/50
# 16/16 [==============================] - 0s 16ms/step - loss: 4.6045e-04
# Epoch 31/50
# 16/16 [==============================] - 0s 16ms/step - loss: 4.6029e-04
# Epoch 32/50
# 16/16 [==============================] - 0s 18ms/step - loss: 4.6060e-04
# Epoch 33/50
# 16/16 [==============================] - 0s 17ms/step - loss: 4.6020e-04
# Epoch 34/50
# 16/16 [==============================] - 0s 17ms/step - loss: 4.6032e-04
# Epoch 35/50
# 16/16 [==============================] - 0s 17ms/step - loss: 4.6056e-04
# Epoch 36/50
# 16/16 [==============================] - 0s 16ms/step - loss: 4.6030e-04
# Epoch 37/50
# 16/16 [==============================] - 0s 15ms/step - loss: 4.6029e-04
# Epoch 38/50
# 16/16 [==============================] - 0s 16ms/step - loss: 4.6033e-04
# Epoch 39/50
# 16/16 [==============================] - 0s 17ms/step - loss: 4.6089e-04
# Epoch 40/50
# 16/16 [==============================] - 0s 16ms/step - loss: 4.6040e-04
# Epoch 41/50
# 16/16 [==============================] - 0s 17ms/step - loss: 4.6072e-04
# Epoch 42/50
# 16/16 [==============================] - 0s 17ms/step - loss: 4.6156e-04
# Epoch 43/50
# 16/16 [==============================] - 0s 17ms/step - loss: 4.6151e-04
# Epoch 44/50
# 16/16 [==============================] - 0s 17ms/step - loss: 4.6039e-04
# Epoch 45/50
# 16/16 [==============================] - 0s 16ms/step - loss: 4.6028e-04
# Epoch 46/50
# 16/16 [==============================] - 0s 17ms/step - loss: 4.6025e-04
# Epoch 47/50
# 16/16 [==============================] - 0s 17ms/step - loss: 4.6041e-04
# Epoch 48/50
# 16/16 [==============================] - 0s 15ms/step - loss: 4.6118e-04
# Epoch 49/50
# 16/16 [==============================] - 0s 17ms/step - loss: 4.6107e-04
# Epoch 50/50
# 16/16 [==============================] - 0s 16ms/step - loss: 4.6144e-04

# %%
y_pred = model.predict(X_test)
# Out:
# 8/8 [==============================] - 1s 5ms/step

# %%
plt.figure(figsize=(12, 6))
plt.title('Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Normalized Close Price')


plt.plot(test_data.index[sequence_length:], test_data['Close'][sequence_length:], label='Actual', color='blue')


plt.plot(test_data.index[sequence_length:], y_pred, label='Predicted', color='orange')

plt.legend()
plt.show()

# %% [markdown]
# # New section
